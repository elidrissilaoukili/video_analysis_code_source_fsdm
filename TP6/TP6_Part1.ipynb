# %% [markdown]
# Mohammed elidrissi laoukili
# * subjet  : video analysis

# %%
import cv2 
import numpy as np 

# Load the video 
cap = cv2.VideoCapture(0) 

# Read the first frame 
ret, frame1 = cap.read() 
prev_gray = cv2.cvtColor(frame1, cv2.COLOR_BGR2GRAY) 

# Prepare to display the results 
while(cap.isOpened()): 
    ret, frame2 = cap.read() 
    if not ret: 
        break 
    next_gray = cv2.cvtColor(frame2, cv2.COLOR_BGR2GRAY) 

    # Calculate optical flow with Farneback 
    flow = cv2.calcOpticalFlowFarneback(prev_gray, next_gray, None, 0.5, 3, 15, 3, 5, 1.2, 0) 

    # Visualize the optical flow with a color map 
    magnitude, angle = cv2.cartToPolar(flow[..., 0], flow[..., 1]) 
    hsv = np.zeros_like(frame1) 
    hsv[..., 1] = 255 
    hsv[..., 0] = angle * 180 / np.pi / 2 
    hsv[..., 2] = cv2.normalize(magnitude, None, 0, 255, cv2.NORM_MINMAX) 
    flow_rgb = cv2.cvtColor(hsv, cv2.COLOR_HSV2BGR) 
    cv2.imshow('Optical Flow Farneback', flow_rgb) 

    # Move to the next frame 
    prev_gray = next_gray 
    if cv2.waitKey(1) & 0xFF == ord('q'): 
        break

cap.release() 
cv2.destroyAllWindows()
